# %%
from helper_functions import load_tfrecord_dataset, parse_tfrecord_fn, predict, decode_output, display_record

# %%
test_dataset = load_tfrecord_dataset('tfrecords/train.tfrecord')

# %%
record_number = int(input("Enter the record number you'd like to display: "))

display_record(test_dataset, record_number)
# Out:
# Record 6:
# Label: Benign
# 1/1 [==============================] - 0s 110ms/step
# VGG16 Model Prediction:  Benign
# 1/1 [==============================] - 0s 324ms/step
# ResNet Model Prediction:  Benign
